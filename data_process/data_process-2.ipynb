# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
rating = pd.read_table("data/rating.gz")
akas = pd.read_table("data/akas.gz", low_memory=False)
basics = pd.read_table("data/basics.tsv", low_memory=False)

# %%
def transform_data(rating, basics):
    movie_info = basics[(basics.titleType == 'movie') & (basics.isAdult == '0')]
    movie = pd.merge(movie_info, rating, on = 'tconst', how = 'inner')
    movie = movie.drop(columns = ['isAdult', 'endYear', 'titleType', 'originalTitle'])
    movie.loc[movie["runtimeMinutes"] == "\\N", "runtimeMinutes"] = "95"
    movie["runtimeMinutes"] = movie["runtimeMinutes"].astype(int)
    movie = movie[movie["numVotes"] > 10000]
    movie["startYear"] = movie["startYear"].astype(int)
    movie = movie.rename(columns = {"tconst":"tid", "primaryTitle":"title", "startYear":"year", 
                        "runtimeMinutes":"length", "averageRating":"rating", "numVotes":"votes"})
    genre = pd.DataFrame(columns = ["tid", "genre"])
    genres = movie[["tid", "genres"]]
    for ind, data in genres.iterrows():
        tid, y = data
        amount = y.split(',')
        for z in amount:
            genre.loc[len(genre.index)] = [tid, z]
    movie = movie.drop(columns = "genres")
    return movie, genre

# %%
'''
import requests
for __, row in movie.iterrows():
    body = {"tid":row["tid"],"title":row["title"], "year":row["year"], "length":row["length"], "rating":row["rating"], "votes":row["votes"]}
    url = "http://localhost:5001/movie"
    requests.put(url, body)
for __, row in genre.iterrows():
    body = {"tid":row["tid"], "genre":row["genre"]}
    url = "http://localhost:5001/genre"
    requests.post(url, body)
'''

# %%
movie, genre = transform_data(rating, basics)

# %%
principal = pd.read_table("data/principals.gz")
actor_info = pd.read_table("data/name.gz")

# %%
principal = principal[(principal.category == 'actress') | (principal.category == 'actor')| (principal.category == 'director')]

# %%
principal = principal.drop(columns = "job")

# %%
principal
# Out:
#              tconst  ordering      nconst  category  \
# 1         tt0000001         2   nm0005690  director
# 3         tt0000002         1   nm0721526  director
# 5         tt0000003         1   nm0721526  director
# 9         tt0000004         1   nm0721526  director
# 11        tt0000005         1   nm0443482     actor
# ...             ...       ...         ...       ...
# 52606336  tt9916880         1   nm1483166     actor
# 52606337  tt9916880         2   nm0254176   actress
# 52606338  tt9916880         3   nm0286175     actor
# 52606339  tt9916880         4  nm10535738   actress
# 52606340  tt9916880         5   nm0996406  director
#
#                                               characters
# 1                                                     \N
# 3                                                     \N
# 5                                                     \N
# 9                                                     \N
# 11                                        ["Blacksmith"]
# ...                                                  ...
# 52606336  ["Rude Ralph","Mischievous Mike","Jolly Josh"]
# 52606337                              ["Moody Margaret"]
# 52606338             ["Dad","Aerobic Al","Nasty Nicola"]
# 52606339                                ["Horrid Henry"]
# 52606340                                              \N
#
# [26661488 rows x 5 columns]

# %%
value = movie.tid.unique()

# %%
principal = principal[principal['tconst'].isin(value)]

# %%
actor_info = actor_info[(actor_info['birthYear'] != '\\N')&(~actor_info["primaryProfession"].isna())]

# %%
actor_info
# Out:
#              nconst      primaryName birthYear deathYear  \
# 0         nm0000001     Fred Astaire      1899      1987
# 1         nm0000002    Lauren Bacall      1924      2014
# 2         nm0000003  Brigitte Bardot      1934        \N
# 3         nm0000004     John Belushi      1949      1982
# 4         nm0000005   Ingmar Bergman      1918      2007
# ...             ...              ...       ...       ...
# 12007287  nm9993379  Fanny Hozleiter      1988        \N
# 12007333  nm9993435     William Riva      1919      1999
# 12007334  nm9993436   Frank J. Gaily      1915      2008
# 12007424  nm9993535    Henry Lawfull      2006        \N
# 12007563  nm9993693      Apsara Rani      1996        \N
#
#                             primaryProfession  \
# 0              soundtrack,actor,miscellaneous
# 1                          actress,soundtrack
# 2         actress,soundtrack,music_department
# 3                     actor,soundtrack,writer
# 4                       writer,director,actor
# ...                                       ...
# 12007287              director,actress,writer
# 12007333                        set_decorator
# 12007334                     sound_department
# 12007424                                actor
# 12007563                              actress
#
#                                      knownForTitles
# 0           tt0031983,tt0072308,tt0050419,tt0053137
# 1           tt0038355,tt0037382,tt0075213,tt0117057
# 2           tt0054452,tt0056404,tt0057345,tt0049189
# 3           tt0072562,tt0078723,tt0080455,tt0077975
# 4           tt0083922,tt0050986,tt0060827,tt0069467
# ...                                             ...
# 12007287                                  tt8743182
# 12007333                        tt0300836,tt0189339
# 12007334                                  tt0189339
# 12007424                       tt10187208,tt5900600
# 12007563  tt13847502,tt8737752,tt12856788,tt8302382
#
# [491270 rows x 6 columns]

# %%
val = principal['nconst'].unique()

# %%
actor_info = actor_info[actor_info['nconst'].isin(val)]

# %%
actor_info
# Out:
#              nconst          primaryName birthYear deathYear  \
# 0         nm0000001         Fred Astaire      1899      1987
# 1         nm0000002        Lauren Bacall      1924      2014
# 2         nm0000003      Brigitte Bardot      1934        \N
# 3         nm0000004         John Belushi      1949      1982
# 4         nm0000005       Ingmar Bergman      1918      2007
# ...             ...                  ...       ...       ...
# 11905864  nm9875384          Milena Smit      1996        \N
# 11907587  nm9877392  Roman Griffin Davis      2007        \N
# 11930512  nm9903838         Sofia Kappel      1998        \N
# 11951942  nm9928618       Roberto Farías      1969        \N
# 11995550  nm9979692      Emir Ali Dogrul      2011        \N
#
#                             primaryProfession  \
# 0              soundtrack,actor,miscellaneous
# 1                          actress,soundtrack
# 2         actress,soundtrack,music_department
# 3                     actor,soundtrack,writer
# 4                       writer,director,actor
# ...                                       ...
# 11905864                       actress,writer
# 11907587                                actor
# 11930512                              actress
# 11951942                actor,director,writer
# 11995550                                actor
#
#                                      knownForTitles
# 0           tt0031983,tt0072308,tt0050419,tt0053137
# 1           tt0038355,tt0037382,tt0075213,tt0117057
# 2           tt0054452,tt0056404,tt0057345,tt0049189
# 3           tt0072562,tt0078723,tt0080455,tt0077975
# 4           tt0083922,tt0050986,tt0060827,tt0069467
# ...                                             ...
# 11905864  tt4359330,tt12618926,tt7354440,tt15327522
# 11907587                       tt11628854,tt2584384
# 11930512             tt20782072,tt8550054,tt9694594
# 11951942    tt3328948,tt8274328,tt4375438,tt1863321
# 11995550  tt8578422,tt9529500,tt13045890,tt14753620
#
# [15311 rows x 6 columns]

# %%
principal = principal.drop(columns = 'ordering')

# %%
principal
# Out:
#              tconst     nconst  category  \
# 28216     tt0004972  nm0001273   actress
# 28217     tt0004972  nm0550615   actress
# 28218     tt0004972  nm0910400     actor
# 28219     tt0004972  nm0178270   actress
# 28220     tt0004972  nm0000428  director
# ...             ...        ...       ...
# 52580819  tt9907782  nm2933542     actor
# 52580820  tt9907782  nm0717709   actress
# 52580821  tt9907782  nm0677944     actor
# 52580822  tt9907782  nm3646923   actress
# 52580823  tt9907782  nm1193346  director
#
#                                            characters
# 28216                 ["Elsie - Stoneman's Daughter"]
# 28217              ["Flora Cameron - The Pet Sister"]
# 28218     ["Col. Ben Cameron aka The Little Colonel"]
# 28219         ["Margaret Cameron - The Elder Sister"]
# 28220                                              \N
# ...                                               ...
# 52580819                             ["John McBride"]
# 52580820                         ["Isabelle Laurent"]
# 52580821                           ["Seamus Laurent"]
# 52580822                                    ["Anais"]
# 52580823                                           \N
#
# [50676 rows x 4 columns]

# %%
actor_info
# Out:
#              nconst          primaryName birthYear deathYear  \
# 0         nm0000001         Fred Astaire      1899      1987
# 1         nm0000002        Lauren Bacall      1924      2014
# 2         nm0000003      Brigitte Bardot      1934        \N
# 3         nm0000004         John Belushi      1949      1982
# 4         nm0000005       Ingmar Bergman      1918      2007
# ...             ...                  ...       ...       ...
# 11905864  nm9875384          Milena Smit      1996        \N
# 11907587  nm9877392  Roman Griffin Davis      2007        \N
# 11930512  nm9903838         Sofia Kappel      1998        \N
# 11951942  nm9928618       Roberto Farías      1969        \N
# 11995550  nm9979692      Emir Ali Dogrul      2011        \N
#
#                             primaryProfession  \
# 0              soundtrack,actor,miscellaneous
# 1                          actress,soundtrack
# 2         actress,soundtrack,music_department
# 3                     actor,soundtrack,writer
# 4                       writer,director,actor
# ...                                       ...
# 11905864                       actress,writer
# 11907587                                actor
# 11930512                              actress
# 11951942                actor,director,writer
# 11995550                                actor
#
#                                      knownForTitles
# 0           tt0031983,tt0072308,tt0050419,tt0053137
# 1           tt0038355,tt0037382,tt0075213,tt0117057
# 2           tt0054452,tt0056404,tt0057345,tt0049189
# 3           tt0072562,tt0078723,tt0080455,tt0077975
# 4           tt0083922,tt0050986,tt0060827,tt0069467
# ...                                             ...
# 11905864  tt4359330,tt12618926,tt7354440,tt15327522
# 11907587                       tt11628854,tt2584384
# 11930512             tt20782072,tt8550054,tt9694594
# 11951942    tt3328948,tt8274328,tt4375438,tt1863321
# 11995550  tt8578422,tt9529500,tt13045890,tt14753620
#
# [15311 rows x 6 columns]

# %%
knownFor = actor_info[['nconst', 'knownForTitles']]

# %%
famousFor = pd.DataFrame(columns = ['nconst', 'known'])

# %%
for ind, data in knownFor.iterrows():
        tid, y = data
        amount = y.split(',')
        for z in amount:
            famousFor.loc[len(famousFor.index)] = [tid, z]

# %%
famousFor
# Out:
#           nconst       known
# 0      nm0000001   tt0031983
# 1      nm0000001   tt0072308
# 2      nm0000001   tt0050419
# 3      nm0000001   tt0053137
# 4      nm0000002   tt0038355
# ...          ...         ...
# 60471  nm9928618   tt1863321
# 60472  nm9979692   tt8578422
# 60473  nm9979692   tt9529500
# 60474  nm9979692  tt13045890
# 60475  nm9979692  tt14753620
#
# [60476 rows x 2 columns]

# %%
principal.loc[principal.category != 'director', 'characters'] = principal.loc[principal.category != 'director', 'characters'].apply(lambda x : x[2:len(x) - 2].split(',')[0])

# %%
principal
# Out:
#              tconst     nconst  category  \
# 28216     tt0004972  nm0001273   actress
# 28217     tt0004972  nm0550615   actress
# 28218     tt0004972  nm0910400     actor
# 28219     tt0004972  nm0178270   actress
# 28220     tt0004972  nm0000428  director
# ...             ...        ...       ...
# 52580819  tt9907782  nm2933542     actor
# 52580820  tt9907782  nm0717709   actress
# 52580821  tt9907782  nm0677944     actor
# 52580822  tt9907782  nm3646923   actress
# 52580823  tt9907782  nm1193346  director
#
#                                        characters
# 28216                 Elsie - Stoneman's Daughter
# 28217              Flora Cameron - The Pet Sister
# 28218     Col. Ben Cameron aka The Little Colonel
# 28219         Margaret Cameron - The Elder Sister
# 28220                                          \N
# ...                                           ...
# 52580819                             John McBride
# 52580820                         Isabelle Laurent
# 52580821                           Seamus Laurent
# 52580822                                    Anais
# 52580823                                       \N
#
# [50676 rows x 4 columns]

# %%
actor_info = actor_info.drop(columns = ('knownForTitles'))

# %%
actor_info.loc[actor_info.deathYear == '\\N', 'deathYear'] = '0'

# %%
actor_info['birthYear'] = actor_info['birthYear'].astype(int)
actor_info['deathYear'] = actor_info['deathYear'].astype(int)

# %%
actor_info
# Out:
#              nconst          primaryName  birthYear  deathYear  \
# 0         nm0000001         Fred Astaire       1899       1987
# 1         nm0000002        Lauren Bacall       1924       2014
# 2         nm0000003      Brigitte Bardot       1934          0
# 3         nm0000004         John Belushi       1949       1982
# 4         nm0000005       Ingmar Bergman       1918       2007
# ...             ...                  ...        ...        ...
# 11905864  nm9875384          Milena Smit       1996          0
# 11907587  nm9877392  Roman Griffin Davis       2007          0
# 11930512  nm9903838         Sofia Kappel       1998          0
# 11951942  nm9928618       Roberto Farías       1969          0
# 11995550  nm9979692      Emir Ali Dogrul       2011          0
#
#                             primaryProfession
# 0              soundtrack,actor,miscellaneous
# 1                          actress,soundtrack
# 2         actress,soundtrack,music_department
# 3                     actor,soundtrack,writer
# 4                       writer,director,actor
# ...                                       ...
# 11905864                       actress,writer
# 11907587                                actor
# 11930512                              actress
# 11951942                actor,director,writer
# 11995550                                actor
#
# [15311 rows x 5 columns]

# %%
import requests
for __, row in famousFor.iterrows():
    body = {"uid":row["nconst"],"tid":row["known"]}
    url = "http://localhost:5001/famous"
    requests.put(url, body)
    
for __, row in principal.iterrows():
    body = {"uid":row["nconst"], "tid":row["tconst"], "category":row["category"], "characters":row["characters"]}
    url = "http://localhost:5001/crew"
    requests.put(url, body)
    
for __, row in actor_info.iterrows():
    body = {
        "uid":row["nconst"],
        "name":row["primaryName"],
        "birthYear":row["birthYear"],
        "deathYear":row["deathYear"],
        "primaryProfession":row["primaryProfession"]
    }
    
    url = "http://localhost:5001/info"
    requests.put(url, body)

# %%
actor_info
# Out:
#              nconst          primaryName  birthYear  deathYear  \
# 0         nm0000001         Fred Astaire       1899       1987
# 1         nm0000002        Lauren Bacall       1924       2014
# 2         nm0000003      Brigitte Bardot       1934          0
# 3         nm0000004         John Belushi       1949       1982
# 4         nm0000005       Ingmar Bergman       1918       2007
# ...             ...                  ...        ...        ...
# 11905864  nm9875384          Milena Smit       1996          0
# 11907587  nm9877392  Roman Griffin Davis       2007          0
# 11930512  nm9903838         Sofia Kappel       1998          0
# 11951942  nm9928618       Roberto Farías       1969          0
# 11995550  nm9979692      Emir Ali Dogrul       2011          0
#
#                             primaryProfession
# 0              soundtrack,actor,miscellaneous
# 1                          actress,soundtrack
# 2         actress,soundtrack,music_department
# 3                     actor,soundtrack,writer
# 4                       writer,director,actor
# ...                                       ...
# 11905864                       actress,writer
# 11907587                                actor
# 11930512                              actress
# 11951942                actor,director,writer
# 11995550                                actor
#
# [15311 rows x 5 columns]
